# %%
# !pip install paddlepaddle==3.0.0
# !pip install paddleocr==2.9.1
# !apt-get update
# !apt-get install -y poppler-utils
# !pip install pdf2image

# %%
import sys
import subprocess

packages = [
    "paddlepaddle==3.0.0",
    "paddleocr==2.9.1",
    "pdf2image"
]

for package in packages:
    subprocess.check_call([
        sys.executable, "-m", "pip", "install", package
    ])

print("✅ Python paddle dependencies installed.")

# %%
import sys
import subprocess

packages = [
    "marker-pdf==1.7.1"
]

for package in packages:
    subprocess.check_call([
        sys.executable, "-m", "pip", "install", package
    ])

print("✅ Python marker dependencies installed.")

# %%
import sys
import subprocess

packages = [
    "pytesseract"
]

for package in packages:
    subprocess.check_call([
        sys.executable, "-m", "pip", "install", package
    ])

print("✅ Python tesseract dependencies installed.")

# %%
#!apt-get update
#!apt-get install -y tesseract-ocr
#!apt-get install -y poppler-utils

#!pip install pytesseract
#!pip install pdf2image

# pip install jupyter nbconvert

# %%
# import sys
# import subprocess
# import shutil
# import os

# # ============================================================
# # 1. Install Python packages in the current .venv
# # ============================================================

# packages = [
#     "pytesseract"
# ]

# for package in packages:
#     print(f"\nInstalling {package}...")
#     subprocess.check_call([
#         sys.executable,
#         "-m",
#         "pip",
#         "install",
#         package
#     ])


# # ============================================================
# # 2. Install Tesseract OCR on Windows
# # ============================================================

# if os.name == "nt":
#     tesseract_path = shutil.which("tesseract")

#     if tesseract_path:
#         print(f"\nTesseract already installed:")
#         print(tesseract_path)

#     else:
#         print("\nTesseract not found. Installing with winget...")

#         subprocess.check_call([
#             "winget",
#             "install",
#             "--id",
#             "UB-Mannheim.TesseractOCR",
#             "-e",
#             "--accept-package-agreements",
#             "--accept-source-agreements"
#         ])

#         print("\nTesseract installation completed.")


# # ============================================================
# # 3. Verify Tesseract
# # ============================================================

# tesseract_path = shutil.which("tesseract")

# if tesseract_path:
#     print(f"\n✅ Tesseract found at:")
#     print(tesseract_path)
# else:
#     print(
#         "\n⚠️ Tesseract was installed, but the current Python process "
#         "cannot see it on PATH yet."
#     )
#     print(
#         "Restart the terminal/FastAPI process before running the OCR runner."
#     )


# # ============================================================
# # 4. Verify Poppler
# # ============================================================

# POPPLER_PATH = r"C:\poppler-26.02.0\Library\bin"

# pdfinfo_path = os.path.join(POPPLER_PATH, "pdfinfo.exe")
# pdftoppm_path = os.path.join(POPPLER_PATH, "pdftoppm.exe")

# print("\nChecking Poppler...")

# if os.path.exists(pdfinfo_path) and os.path.exists(pdftoppm_path):
#     print("✅ Poppler found:")
#     print(POPPLER_PATH)
# else:
#     print("❌ Poppler was not found at:")
#     print(POPPLER_PATH)


# # ============================================================
# # 5. Final verification
# # ============================================================

# print("\n================================================")
# print("SETUP VERIFICATION")
# print("================================================")

# print(f"Python: {sys.executable}")

# print("\nPython packages:")

# try:
#     import pytesseract
#     print(f"✅ pytesseract: {pytesseract.__version__}")
# except Exception as e:
#     print(f"❌ pytesseract: {e}")

# try:
#     from pdf2image import convert_from_path
#     print("✅ pdf2image installed")
# except Exception as e:
#     print(f"❌ pdf2image: {e}")

# if shutil.which("tesseract"):
#     print("✅ Tesseract executable available")
# else:
#     print("⚠️ Tesseract executable not visible yet")

# if os.path.exists(pdfinfo_path):
#     print("✅ Poppler available")
# else:
#     print("❌ Poppler unavailable")

# print("\n✅ Setup verification completed.")
# Out:
# Installing pytesseract...
#
# Installing pdf2image...
#
# Tesseract not found. Installing with winget...
